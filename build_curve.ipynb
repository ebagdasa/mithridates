# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from ray.tune import ExperimentAnalysis

# %%
from mithridates.utils import get_inflection_point

# %%
# locate output of ray:
analysis = ExperimentAnalysis('/home/eugene/ray_results/tune_run_2023-02-07_12-25-36')

# %%
res = get_inflection_point(analysis, simplified=False, plot=True)
# Out:
# Looking for inflection point with second derivative
# Inflection point is at 0.083% of the training dataset and backdoor accuracy: 30.700%

# %%
res = get_inflection_point(analysis, simplified=True, plot=True)
# Out:
# Using simplified threshold: of 50 for backdoor accuracy.
# Inflection point is at 0.091% of the training dataset and backdoor accuracy: 75.050%
